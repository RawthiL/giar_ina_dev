# %% [markdown]
# # Libreries

# %%
import os
import random
import itertools
import numpy as np
import matplotlib.pyplot as plt

import tensorflow as tf
import keras
import pandas as pd
from keras import layers


from sklearn.metrics import accuracy_score, recall_score, confusion_matrix, precision_score

from tensorflow.keras.applications import VGG16, VGG19, ResNet50, InceptionV3, DenseNet121, MobileNetV2
from tensorflow.keras.layers import Dense, Flatten, BatchNormalization
from tensorflow.keras.models import Model
from tensorflow.keras import regularizers
# Out:
# 2025-03-25 13:51:11.156738: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-03-25 13:51:11.225751: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1742921471.250754    4780 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1742921471.260518    4780 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-03-25 13:51:11.323943: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI AVX512_BF16 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# # Definitions

# %%
pwd
# Out:
# '/home/nicolas/Documentos/UTN/INA/giar_ina_dev/notebooks/train'

# %%
train_path = "../../output/dataset_test/AutoEncoder_agglomerative_v2/train/"
validation_path = "../../output/dataset_test/AutoEncoder_agglomerative_v2/validation"
test_path = "../../output/dataset_test/test_roboflow/"

# train_path = "../../output/cropped_cells_onion/media/train"
# validation_path = "../../output/cropped_cells_onion/media/valid"
# test_path = "../../output/cropped_cells_onion/media/test/"

encoder_path = "../../models/encoder_SSIM_MAE_Bparams.keras"
save_path="../../output/results"

# %%
SHAPE = (128,128,1)
batch_size = 48
TRAIN_ENCODER = False
COLOR_MODE="grayscale"

# %% [markdown]
# # Confusion matrix

# %%
def plot_confusion_matrix(cm, classes, title='Confusion matrix', cmap=plt.cm.Blues):

    cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title, fontsize=25)
    #plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=90, fontsize=15)
    plt.yticks(tick_marks, classes, fontsize=15)

    fmt = '.2f'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black", fontsize = 14)

    plt.ylabel('True label', fontsize=20)
    plt.xlabel('Predicted label', fontsize=20)

# %%
results = []
def plot_conf_matrix(model, generator, titulo='Confusion matrix'):
    ### RETRIVE TEST LABEL FROM GENERATOR ###
    test_num = sum(1 for _ in generator)
    label_test = []
    pred_test = []

    for i, batch in enumerate(generator):
        X, y = batch
        label_test.append(y.numpy())
        predictions = model.predict(X)
        pred_test.append(predictions)

    label_test = np.argmax(np.vstack(label_test), axis=1)


    ### COMPUTE PREDICTIONS ON TEST DATA ###
    pred_test = np.argmax(np.vstack(pred_test), axis=1)
    accuracy=accuracy_score(label_test, pred_test)
    recall=recall_score(label_test, pred_test,pos_label=0)
    specificity=recall_score(label_test, pred_test,pos_label=1)
    precision = precision_score(label_test, pred_test, pos_label=0)
    # pred_test = pred_test[:label_test.shape[0],]
    ### ACCURACY ON TEST DATA ###
    print("-" * 40)
    print('ACCURACY:', accuracy)
    print('RECALL:',recall)
    print('PRECISION:', precision)
    print('SPECIFICITY:',specificity)
    print("-" * 40)
    print("\n")
    ### CONFUSION MATRIX ON TEST DATA ###
    cnf_matrix = confusion_matrix(label_test, pred_test)
    results.append({'Model': titulo, 'Accuracy': accuracy , 'Recall':recall,'Precision':precision,'Specificity':specificity})

    plt.figure(figsize=(7,7))
    plot_confusion_matrix(cnf_matrix, classes=['cell', 'not'], title=titulo)
    plt.title(titulo)
    plt.show()

# %% [markdown]
# # Datasets

# %%
# data generator function
def data_gen ():
    train_generator = tf.keras.utils.image_dataset_from_directory(
        train_path,
        labels="inferred",
        label_mode="categorical",
        batch_size=batch_size,
        image_size=(SHAPE[0], SHAPE[1]),
        color_mode=COLOR_MODE,
        shuffle=True,
        seed=42
    )
    train_generator = train_generator.map(
        lambda x, y: (x / 255.0, y),
        num_parallel_calls=tf.data.AUTOTUNE
    )
    train_generator = train_generator.prefetch(buffer_size=tf.data.AUTOTUNE)


    validation_generator = tf.keras.utils.image_dataset_from_directory(
        validation_path,
        labels="inferred",
        label_mode="categorical",
        batch_size=batch_size,
        image_size=(SHAPE[0], SHAPE[1]),
        color_mode=COLOR_MODE,
        shuffle=True,
        seed=42
    )
    validation_generator = validation_generator.map(
        lambda x, y: (x / 255.0, y),
        num_parallel_calls=tf.data.AUTOTUNE
    )
    validation_generator = validation_generator.prefetch(buffer_size=tf.data.AUTOTUNE)



    test_generator = tf.keras.utils.image_dataset_from_directory(
        test_path,
        labels="inferred",
        label_mode="categorical",
        batch_size=batch_size,
        image_size=(SHAPE[0], SHAPE[1]),
        color_mode=COLOR_MODE,
        shuffle=True,
        seed=42
    )
    test_generator = test_generator.map(
        lambda x, y: (x / 255.0, y),
        num_parallel_calls=tf.data.AUTOTUNE
    )
    test_generator = test_generator.prefetch(buffer_size=tf.data.AUTOTUNE)


    return train_generator,validation_generator,test_generator

# %%
# plot images

file_paths = []
labels = []

for label_dir in os.listdir(train_path):
    label_dir_path = os.path.join(train_path, label_dir)
    if os.path.isdir(label_dir_path):
        for image_name in os.listdir(label_dir_path):
            if image_name.endswith(('.png', '.jpg', '.jpeg')):
                file_paths.append(os.path.join(label_dir_path, image_name))
                labels.append(label_dir)
train_generator = tf.keras.utils.image_dataset_from_directory(
    train_path,
    labels="inferred",
    label_mode="categorical",
    batch_size=batch_size,
    image_size=(SHAPE[0], SHAPE[1]),
    color_mode=COLOR_MODE,
    shuffle=False,
)



for images, labels in train_generator:
    print(images.shape)
    print(labels.shape)

    #filenames_in_batch = [train_generator.filenames[idx] for idx in train_generator.index_array]

    plt.figure(figsize=(10, 10))

    for i in range(4):
        directory, file_name = os.path.split(file_paths[i])
        folder_name = os.path.basename(directory)
        ax = plt.subplot(2, 2, i + 1)
        plt.imshow(np.array(images[i]).astype("uint8"))

        #file_name = filenames_in_batch[i]
        label = np.argmax(labels[i])
        plt.title(f"Label: {label}\nClase:{folder_name}\nFile: {file_name}", fontsize=10)

        plt.axis("off")

    plt.tight_layout()
    plt.show()
    break
# Out:
# Found 7000 files belonging to 2 classes.
# (48, 128, 128, 1)
# (48, 2)
# I0000 00:00:1742921496.347340    4780 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 20905 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:01:00.0, compute capability: 8.6

# %% [markdown]
# # Model

# %%
def get_model(pretrain_encoder,TRAIN_ENCODER,input_shape):

    encoder=pretrain_encoder

    inp = keras.Input(shape=input_shape)
    x = inp

    encoder.trainable = TRAIN_ENCODER

    x = encoder(x)

    x = layers.Dropout(0.5)(x)
    x = layers.BatchNormalization()(x)

    x = layers.Dense(16, activation='relu', kernel_regularizer=regularizers.l2(0.01))(x)
    x = layers.Dropout(0.5)(x)
    x = layers.Dense(8, activation='relu', kernel_regularizer=regularizers.l2(0.01))(x)
    x = layers.Dropout(0.5)(x)
    x = layers.Dense(4, activation='relu', kernel_regularizer=regularizers.l2(0.01))(x)
    out =layers.Dense(2, activation='linear')(x)


    model = keras.Model(inp, out)

    return model

# %% [markdown]
# # Train

# %%
encoder_name="Encoder_SSIM+MAE"
encoder= keras.saving.load_model(encoder_path)
model = get_model(encoder,TRAIN_ENCODER,SHAPE)

train_generator,validation_generator,test_generator=data_gen()

stopping = keras.callbacks.EarlyStopping(
    monitor="val_loss",
    min_delta=0,
    patience=10,
    verbose=0,
    mode="auto",
    baseline=None,
    restore_best_weights=True,
    start_from_epoch=2,
)


model.compile(
    keras.optimizers.Adam(learning_rate= 0.0001),
    loss=keras.losses.CategoricalCrossentropy(from_logits=True),
    metrics=['accuracy']
)

history = model.fit(train_generator,
          epochs=150,
          validation_data = validation_generator,
          callbacks=[ stopping],
)

metrics = pd.DataFrame(history.history)
metrics[['loss', 'val_loss']].plot()
# Out:
# Found 7000 files belonging to 2 classes.
# Found 6676 files belonging to 2 classes.
# Found 623 files belonging to 2 classes.
# Epoch 1/150
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1742921511.805552    7574 service.cc:148] XLA service 0x7aa3d0006950 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1742921511.805795    7574 service.cc:156]   StreamExecutor device (0): NVIDIA GeForce RTX 3090, Compute Capability 8.6
# 2025-03-25 13:51:51.847358: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1742921511.977210    7574 cuda_dnn.cc:529] Loaded cuDNN version 90701
#  92/146 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5072 - loss: 1.2644
# I0000 00:00:1742921513.101745    7574 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.5101 - loss: 1.2564 - val_accuracy: 0.6983 - val_loss: 1.0017
# Epoch 2/150
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5145 - loss: 1.1551 - val_accuracy: 0.6691 - val_loss: 0.9896
# Epoch 3/150
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5262 - loss: 1.1088 - val_accuracy: 0.6493 - val_loss: 0.9766
# Epoch 4/150
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5331 - loss: 1.0618 - val_accuracy: 0.6507 - val_loss: 0.9604
# Epoch 5/150
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5682 - loss: 1.0171 - val_accuracy: 0.6860 - val_loss: 0.9428
# Epoch 6/150
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5675 - loss: 0.9821 - val_accuracy: 0.7448 - val_loss: 0.9222
# Epoch 7/150
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5760 - loss: 0.9759 - val_accuracy: 0.8165 - val_loss: 0.9026
# Epoch 8/150
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6065 - loss: 0.9399 - val_accuracy: 0.8788 - val_loss: 0.8804
# Epoch 9/150
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6244 - loss: 0.9134 - val_accuracy: 0.9247 - val_loss: 0.8526
# Epoch 10/150
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6286 - loss: 0.8924 - val_accuracy: 0.9416 - val_loss: 0.8230
# Epoch 11/150
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6516 - loss: 0.8637 - val_accuracy: 0.9464 - val_loss: 0.7933
# Epoch 12/150
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6565 - loss: 0.8420 - val_accuracy: 0.9491 - val_loss: 0.7615
# Epoch 13/150
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6681 - loss: 0.8273 - val_accuracy: 0.9477 - val_loss: 0.7309
# Epoch 14/150
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6779 - loss: 0.8062 - val_accuracy: 0.9459 - val_loss: 0.6995
# Epoch 15/150
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6842 - loss: 0.7857 - val_accuracy: 0.9431 - val_loss: 0.6707
# Epoch 16/150
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7192 - loss: 0.7528 - val_accuracy: 0.9417 - val_loss: 0.6397
# Epoch 17/150
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7207 - loss: 0.7455 - val_accuracy: 0.9422 - val_loss: 0.6107
# Epoch 18/150
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7359 - loss: 0.7204 - val_accuracy: 0.9420 - val_loss: 0.5845
# Epoch 19/150
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7610 - loss: 0.7030 - val_accuracy: 0.9425 - val_loss: 0.5538
# Epoch 20/150
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7604 - loss: 0.6844 - val_accuracy: 0.9423 - val_loss: 0.5277
# Epoch 21/150
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7789 - loss: 0.6600 - val_accuracy: 0.9422 - val_loss: 0.5027
# Epoch 22/150
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7801 - loss: 0.6447 - val_accuracy: 0.9432 - val_loss: 0.4786
# Epoch 23/150
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8003 - loss: 0.6184 - val_accuracy: 0.9435 - val_loss: 0.4564
# Epoch 24/150
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7996 - loss: 0.6048 - val_accuracy: 0.9435 - val_loss: 0.4378
# Epoch 25/150
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8064 - loss: 0.5984 - val_accuracy: 0.9440 - val_loss: 0.4195
# Epoch 26/150
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8171 - loss: 0.5714 - val_accuracy: 0.9443 - val_loss: 0.4020
# Epoch 27/150
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8233 - loss: 0.5599 - val_accuracy: 0.9437 - val_loss: 0.3899
# Epoch 28/150
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8272 - loss: 0.5425 - val_accuracy: 0.9449 - val_loss: 0.3753
# Epoch 29/150
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8249 - loss: 0.5436 - val_accuracy: 0.9444 - val_loss: 0.3637
# Epoch 30/150
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8437 - loss: 0.5140 - val_accuracy: 0.9450 - val_loss: 0.3514
# Epoch 31/150
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8464 - loss: 0.5087 - val_accuracy: 0.9464 - val_loss: 0.3423
# Epoch 32/150
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8552 - loss: 0.5001 - val_accuracy: 0.9461 - val_loss: 0.3332
# Epoch 33/150
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8546 - loss: 0.4891 - val_accuracy: 0.9462 - val_loss: 0.3259
# Epoch 34/150
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8542 - loss: 0.4896 - val_accuracy: 0.9465 - val_loss: 0.3192
# Epoch 35/150
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8579 - loss: 0.4734 - val_accuracy: 0.9470 - val_loss: 0.3123
# Epoch 36/150
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8546 - loss: 0.4683 - val_accuracy: 0.9471 - val_loss: 0.3059
# Epoch 37/150
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8546 - loss: 0.4624 - val_accuracy: 0.9479 - val_loss: 0.2998
# Epoch 38/150
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8569 - loss: 0.4562 - val_accuracy: 0.9479 - val_loss: 0.2945
# Epoch 39/150
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8597 - loss: 0.4432 - val_accuracy: 0.9485 - val_loss: 0.2884
# Epoch 40/150
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8698 - loss: 0.4361 - val_accuracy: 0.9480 - val_loss: 0.2832
# Epoch 41/150
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8624 - loss: 0.4290 - val_accuracy: 0.9482 - val_loss: 0.2773
# Epoch 42/150
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8740 - loss: 0.4169 - val_accuracy: 0.9480 - val_loss: 0.2731
# Epoch 43/150
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8724 - loss: 0.4206 - val_accuracy: 0.9486 - val_loss: 0.2685
# Epoch 44/150
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8708 - loss: 0.4144 - val_accuracy: 0.9491 - val_loss: 0.2642
# Epoch 45/150
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8762 - loss: 0.4218 - val_accuracy: 0.9491 - val_loss: 0.2606
# Epoch 46/150
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8741 - loss: 0.4035 - val_accuracy: 0.9492 - val_loss: 0.2562
# Epoch 47/150
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8701 - loss: 0.4091 - val_accuracy: 0.9489 - val_loss: 0.2529
# Epoch 48/150
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8875 - loss: 0.3899 - val_accuracy: 0.9501 - val_loss: 0.2486
# Epoch 49/150
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8801 - loss: 0.3925 - val_accuracy: 0.9500 - val_loss: 0.2457
# Epoch 50/150
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8837 - loss: 0.3825 - val_accuracy: 0.9501 - val_loss: 0.2428
# Epoch 51/150
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8916 - loss: 0.3760 - val_accuracy: 0.9500 - val_loss: 0.2399
# Epoch 52/150
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8855 - loss: 0.3842 - val_accuracy: 0.9498 - val_loss: 0.2371
# Epoch 53/150
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8869 - loss: 0.3752 - val_accuracy: 0.9507 - val_loss: 0.2337
# Epoch 54/150
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8887 - loss: 0.3794 - val_accuracy: 0.9507 - val_loss: 0.2316
# Epoch 55/150
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8891 - loss: 0.3761 - val_accuracy: 0.9510 - val_loss: 0.2298
# Epoch 56/150
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8933 - loss: 0.3661 - val_accuracy: 0.9507 - val_loss: 0.2271
# Epoch 57/150
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8969 - loss: 0.3616 - val_accuracy: 0.9507 - val_loss: 0.2247
# Epoch 58/150
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8850 - loss: 0.3610 - val_accuracy: 0.9509 - val_loss: 0.2230
# Epoch 59/150
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8856 - loss: 0.3712 - val_accuracy: 0.9510 - val_loss: 0.2204
# Epoch 60/150
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9012 - loss: 0.3430 - val_accuracy: 0.9504 - val_loss: 0.2185
# Epoch 61/150
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8944 - loss: 0.3527 - val_accuracy: 0.9510 - val_loss: 0.2171
# Epoch 62/150
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8967 - loss: 0.3539 - val_accuracy: 0.9507 - val_loss: 0.2155
# Epoch 63/150
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8963 - loss: 0.3441 - val_accuracy: 0.9503 - val_loss: 0.2135
# Epoch 64/150
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8950 - loss: 0.3519 - val_accuracy: 0.9507 - val_loss: 0.2127
# Epoch 65/150
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8994 - loss: 0.3493 - val_accuracy: 0.9507 - val_loss: 0.2117
# Epoch 66/150
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9023 - loss: 0.3386 - val_accuracy: 0.9509 - val_loss: 0.2099
# Epoch 67/150
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8950 - loss: 0.3337 - val_accuracy: 0.9504 - val_loss: 0.2082
# Epoch 68/150
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8944 - loss: 0.3367 - val_accuracy: 0.9504 - val_loss: 0.2066
# Epoch 69/150
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8989 - loss: 0.3356 - val_accuracy: 0.9507 - val_loss: 0.2056
# Epoch 70/150
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8948 - loss: 0.3410 - val_accuracy: 0.9504 - val_loss: 0.2049
# Epoch 71/150
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8909 - loss: 0.3351 - val_accuracy: 0.9509 - val_loss: 0.2034
# Epoch 72/150
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8946 - loss: 0.3310 - val_accuracy: 0.9515 - val_loss: 0.2018
# Epoch 73/150
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8931 - loss: 0.3318 - val_accuracy: 0.9510 - val_loss: 0.2013
# Epoch 74/150
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8962 - loss: 0.3323 - val_accuracy: 0.9513 - val_loss: 0.1999
# Epoch 75/150
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9047 - loss: 0.3138 - val_accuracy: 0.9512 - val_loss: 0.1989
# Epoch 76/150
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8956 - loss: 0.3196 - val_accuracy: 0.9522 - val_loss: 0.1976
# Epoch 77/150
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8927 - loss: 0.3215 - val_accuracy: 0.9516 - val_loss: 0.1969
# Epoch 78/150
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9029 - loss: 0.3110 - val_accuracy: 0.9516 - val_loss: 0.1962
# Epoch 79/150
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8987 - loss: 0.3160 - val_accuracy: 0.9518 - val_loss: 0.1951
# Epoch 80/150
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8981 - loss: 0.3246 - val_accuracy: 0.9522 - val_loss: 0.1950
# Epoch 81/150
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8927 - loss: 0.3215 - val_accuracy: 0.9521 - val_loss: 0.1944
# Epoch 82/150
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8954 - loss: 0.3098 - val_accuracy: 0.9534 - val_loss: 0.1933
# Epoch 83/150
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8961 - loss: 0.3180 - val_accuracy: 0.9530 - val_loss: 0.1927
# Epoch 84/150
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9000 - loss: 0.3141 - val_accuracy: 0.9527 - val_loss: 0.1921
# Epoch 85/150
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9025 - loss: 0.3088 - val_accuracy: 0.9527 - val_loss: 0.1916
# Epoch 86/150
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8974 - loss: 0.3095 - val_accuracy: 0.9533 - val_loss: 0.1910
# Epoch 87/150
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8970 - loss: 0.3134 - val_accuracy: 0.9531 - val_loss: 0.1904
# Epoch 88/150
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8933 - loss: 0.3152 - val_accuracy: 0.9527 - val_loss: 0.1899
# Epoch 89/150
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9043 - loss: 0.2945 - val_accuracy: 0.9530 - val_loss: 0.1890
# Epoch 90/150
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9007 - loss: 0.3011 - val_accuracy: 0.9525 - val_loss: 0.1888
# Epoch 91/150
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8960 - loss: 0.3028 - val_accuracy: 0.9530 - val_loss: 0.1879
# Epoch 92/150
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9087 - loss: 0.2955 - val_accuracy: 0.9527 - val_loss: 0.1872
# Epoch 93/150
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8967 - loss: 0.2998 - val_accuracy: 0.9534 - val_loss: 0.1868
# Epoch 94/150
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8975 - loss: 0.3097 - val_accuracy: 0.9527 - val_loss: 0.1867
# Epoch 95/150
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9001 - loss: 0.3090 - val_accuracy: 0.9528 - val_loss: 0.1864
# Epoch 96/150
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8925 - loss: 0.3108 - val_accuracy: 0.9528 - val_loss: 0.1859
# Epoch 97/150
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8987 - loss: 0.3057 - val_accuracy: 0.9528 - val_loss: 0.1854
# Epoch 98/150
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8959 - loss: 0.3047 - val_accuracy: 0.9527 - val_loss: 0.1849
# Epoch 99/150
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8990 - loss: 0.3002 - val_accuracy: 0.9533 - val_loss: 0.1848
# Epoch 100/150
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9050 - loss: 0.2973 - val_accuracy: 0.9527 - val_loss: 0.1841
# Epoch 101/150
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9032 - loss: 0.3004 - val_accuracy: 0.9530 - val_loss: 0.1836
# Epoch 102/150
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9054 - loss: 0.2943 - val_accuracy: 0.9525 - val_loss: 0.1833
# Epoch 103/150
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8969 - loss: 0.3034 - val_accuracy: 0.9527 - val_loss: 0.1828
# Epoch 104/150
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9009 - loss: 0.3017 - val_accuracy: 0.9531 - val_loss: 0.1825
# Epoch 105/150
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8968 - loss: 0.3027 - val_accuracy: 0.9530 - val_loss: 0.1821
# Epoch 106/150
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8972 - loss: 0.2941 - val_accuracy: 0.9525 - val_loss: 0.1817
# Epoch 107/150
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9002 - loss: 0.2945 - val_accuracy: 0.9537 - val_loss: 0.1814
# Epoch 108/150
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8950 - loss: 0.2961 - val_accuracy: 0.9537 - val_loss: 0.1813
# Epoch 109/150
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8993 - loss: 0.2912 - val_accuracy: 0.9534 - val_loss: 0.1808
# Epoch 110/150
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8950 - loss: 0.3053 - val_accuracy: 0.9539 - val_loss: 0.1803
# Epoch 111/150
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9031 - loss: 0.2863 - val_accuracy: 0.9531 - val_loss: 0.1798
# Epoch 112/150
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9079 - loss: 0.2808 - val_accuracy: 0.9533 - val_loss: 0.1795
# Epoch 113/150
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8974 - loss: 0.3004 - val_accuracy: 0.9534 - val_loss: 0.1796
# Epoch 114/150
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8991 - loss: 0.2917 - val_accuracy: 0.9534 - val_loss: 0.1792
# Epoch 115/150
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9067 - loss: 0.2871 - val_accuracy: 0.9533 - val_loss: 0.1790
# Epoch 116/150
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8992 - loss: 0.3006 - val_accuracy: 0.9537 - val_loss: 0.1793
# Epoch 117/150
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8997 - loss: 0.2961 - val_accuracy: 0.9536 - val_loss: 0.1791
# Epoch 118/150
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9038 - loss: 0.2919 - val_accuracy: 0.9534 - val_loss: 0.1786
# Epoch 119/150
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8987 - loss: 0.2961 - val_accuracy: 0.9530 - val_loss: 0.1786
# Epoch 120/150
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8941 - loss: 0.2916 - val_accuracy: 0.9533 - val_loss: 0.1784
# Epoch 121/150
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9001 - loss: 0.2890 - val_accuracy: 0.9531 - val_loss: 0.1781
# Epoch 122/150
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8998 - loss: 0.2866 - val_accuracy: 0.9531 - val_loss: 0.1775
# Epoch 123/150
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9016 - loss: 0.2916 - val_accuracy: 0.9533 - val_loss: 0.1769
# Epoch 124/150
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8992 - loss: 0.2836 - val_accuracy: 0.9533 - val_loss: 0.1764
# Epoch 125/150
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9008 - loss: 0.2928 - val_accuracy: 0.9533 - val_loss: 0.1762
# Epoch 126/150
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9086 - loss: 0.2875 - val_accuracy: 0.9533 - val_loss: 0.1759
# Epoch 127/150
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9014 - loss: 0.2965 - val_accuracy: 0.9531 - val_loss: 0.1758
# Epoch 128/150
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8998 - loss: 0.2842 - val_accuracy: 0.9534 - val_loss: 0.1752
# Epoch 129/150
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9063 - loss: 0.2855 - val_accuracy: 0.9534 - val_loss: 0.1747
# Epoch 130/150
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8972 - loss: 0.2844 - val_accuracy: 0.9533 - val_loss: 0.1745
# Epoch 131/150
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9012 - loss: 0.2874 - val_accuracy: 0.9534 - val_loss: 0.1743
# Epoch 132/150
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8992 - loss: 0.2828 - val_accuracy: 0.9533 - val_loss: 0.1739
# Epoch 133/150
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8910 - loss: 0.3018 - val_accuracy: 0.9534 - val_loss: 0.1743
# Epoch 134/150
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8999 - loss: 0.2899 - val_accuracy: 0.9533 - val_loss: 0.1739
# Epoch 135/150
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8971 - loss: 0.2958 - val_accuracy: 0.9537 - val_loss: 0.1733
# Epoch 136/150
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9041 - loss: 0.2819 - val_accuracy: 0.9539 - val_loss: 0.1733
# Epoch 137/150
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8965 - loss: 0.2909 - val_accuracy: 0.9531 - val_loss: 0.1733
# Epoch 138/150
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9035 - loss: 0.2842 - val_accuracy: 0.9536 - val_loss: 0.1725
# Epoch 139/150
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9067 - loss: 0.2773 - val_accuracy: 0.9533 - val_loss: 0.1723
# Epoch 140/150
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8999 - loss: 0.2880 - val_accuracy: 0.9534 - val_loss: 0.1720
# Epoch 141/150
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9072 - loss: 0.2793 - val_accuracy: 0.9534 - val_loss: 0.1727
# Epoch 142/150
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8972 - loss: 0.2894 - val_accuracy: 0.9540 - val_loss: 0.1721
# Epoch 143/150
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9022 - loss: 0.2962 - val_accuracy: 0.9539 - val_loss: 0.1720
# Epoch 144/150
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9004 - loss: 0.2825 - val_accuracy: 0.9540 - val_loss: 0.1715
# Epoch 145/150
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9052 - loss: 0.2738 - val_accuracy: 0.9537 - val_loss: 0.1716
# Epoch 146/150
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9064 - loss: 0.2820 - val_accuracy: 0.9530 - val_loss: 0.1717
# Epoch 147/150
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8943 - loss: 0.2975 - val_accuracy: 0.9533 - val_loss: 0.1718
# Epoch 148/150
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8977 - loss: 0.2899 - val_accuracy: 0.9542 - val_loss: 0.1715
# Epoch 149/150
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8987 - loss: 0.2903 - val_accuracy: 0.9537 - val_loss: 0.1716
# Epoch 150/150
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9081 - loss: 0.2823 - val_accuracy: 0.9534 - val_loss: 0.1715
# <Axes: >

# %%
model = keras.models.load_model('/home/nicolas/Descargas/model_Encoder_SSIM+MAE.keras')
plot_conf_matrix(model, validation_generator, f'{encoder_name} - Validation')
plot_conf_matrix(model, test_generator, f'{encoder_name} - Test')
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step
# ----------------------------------------
# ACCURACY: 0.7748651887357699
# RECALL: 0.8882241813602015
# PRECISION: 0.7107583774250441
# SPECIFICITY: 0.672
# ----------------------------------------
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step
# ----------------------------------------
# ACCURACY: 0.7030497592295345
# RECALL: 0.6805111821086262
# PRECISION: 0.714765100671141
# SPECIFICITY: 0.7258064516129032
# ----------------------------------------

# %%
model.save(save_path+f'/model_{encoder_name}.keras')

# %%
# Out:
# <Axes: >

# %%
import pandas as pd

results_df = pd.DataFrame(results)

results_df.to_excel(save_path+"/resultados_Encoder_SSIM+MAE.xlsx")

print(results_df)
# Out:
#                            Model  Accuracy    Recall  Precision  Specificity
# 0  Encoder_SSIM+MAE - Validation  0.981332  0.992262   0.965925     0.972857
# 1        Encoder_SSIM+MAE - Test  0.740500  0.558000   0.878740     0.923000
